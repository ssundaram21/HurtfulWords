# %%
import pandas as pd

# %%
df_paths=["/home/nhulkund/6.864/HurtfulWords/outputs/finetuning/phenotype_first",
          "/home/nhulkund/6.864/HurtfulWords/outputs/finetuning/phenotype_all",
          "/home/nhulkund/6.864/HurtfulWords/outputs/finetuning/inhosp_mort"]

# %%
df = pd.read_pickle(df_path)

# %%
test_set=[]
with open(os.path.join(os.path.dirname(__file__), '/home/nhulkund/6.864/mimic3-benchmarks/mimic3-benchmark/resources/testset.csv'), "r") as test_set_file:
    for line in test_set_file:
        x, y = line.split(',')
        if int(y) == 1:
            test_set.add(x)
df['fold'] = df['fold'].where(!df['subject'].isin(test_test),other)
# Out:
# Medicare      8683
# Private       5830
# Medicaid      1437
# Government     475
# Self Pay       264
# Name: insurance, dtype: int64
# M    9498
# F    7191
# Name: gender, dtype: int64
# WHITE                    12095
# UNKNOWN/NOT SPECIFIED     1762
# BLACK                     1542
# HISPANIC/LATINO            556
# OTHER                      369
# ASIAN                      365
# Name: ethnicity_to_use, dtype: int64
# English    8024
# Missing    7269
# Other      1396
# Name: language_to_use, dtype: int64
# 109      21
# 13033    19
# 11861    17
# 5060     14
# 7275     14
#          ..
# 6289      1
# 75217     1
# 81362     1
# 71127     1
# 2047      1
# Name: subject_id, Length: 14876, dtype: int64
# 145988.0    1
# 100387.0    1
# 105366.0    1
# 122505.0    1
# 177243.0    1
#            ..
# 183263.0    1
# 154753.0    1
# 113625.0    1
# 176072.0    1
# 168891.0    1
# Name: hadm_id, Length: 16689, dtype: int64
# ...
